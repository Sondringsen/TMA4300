# %% [markdown]
# <h1> Problem 1 </h1>
# <h2> a) Exploring the Data </h2>

# %%
load(file = "../data/rain.rda")
rain
# Out:
#     day n.years n.rain
# 1    1  39       8
# 2    2  39       7
# 3    3  39       8
# 4    4  39      11
# 5    5  39       8
# 6    6  39       6
# 7    7  39       6
# 8    8  39       4
# 9    9  39       3
# 10  10  39       3
# 11  11  39       5
# 12  12  39       7
# 13  13  39       8
# 14  14  39       5
# 15  15  39       5
# 16  16  39       5
# 17  17  39       2
# 18  18  39       7
# 19  19  39       2
# 20  20  39       3
# 21  21  39       8
# 22  22  39       6
# 23  23  39       5
# 24  24  39       4
# 25  25  39       4
# 26  26  39       7
# 27  27  39       4
# 28  28  39       5
# 29  29  39      10
# 30  30  39      10
# ⋮   ⋮   ⋮       ⋮
# 336 337 39      7
# 337 338 39      6
# 338 339 39      6
# 339 340 39      6
# 340 341 39      5
# 341 342 39      5
# 342 343 39      5
# 343 344 39      6
# 344 345 39      6
# 345 346 39      5
# 346 347 39      4
# 347 348 39      8
# 348 349 39      4
# 349 350 39      5
# 350 351 39      1
# 351 352 39      5
# ...

# %%
summary(rain)
# Out:
#       day            n.years          n.rain
#  Min.   :  1.00   Min.   :10.00   Min.   : 0.00
#  1st Qu.: 92.25   1st Qu.:39.00   1st Qu.: 8.00
#  Median :183.50   Median :39.00   Median :11.00
#  Mean   :183.50   Mean   :38.92   Mean   :10.98
#  3rd Qu.:274.75   3rd Qu.:39.00   3rd Qu.:14.00
#  Max.   :366.00   Max.   :39.00   Max.   :23.00

# %%
options(repr.plot.width = 20, repr.plot.height = 10, repr.plot.bg = "white")
par(bg="white")
plot.ts(rain)
# Out:
# plot without title

# %%
pi <- ts(rain$n.rain / rain$n.years)
pi
# Out:
# A Time Series:
#   [1] 0.20512821 0.17948718 0.20512821 0.28205128 0.20512821 0.15384615
#   [7] 0.15384615 0.10256410 0.07692308 0.07692308 0.12820513 0.17948718
#  [13] 0.20512821 0.12820513 0.12820513 0.12820513 0.05128205 0.17948718
#  [19] 0.05128205 0.07692308 0.20512821 0.15384615 0.12820513 0.10256410
#  [25] 0.10256410 0.17948718 0.10256410 0.12820513 0.25641026 0.25641026
#  [31] 0.17948718 0.17948718 0.15384615 0.12820513 0.12820513 0.20512821
#  [37] 0.15384615 0.20512821 0.17948718 0.28205128 0.20512821 0.07692308
#  [43] 0.10256410 0.12820513 0.15384615 0.23076923 0.20512821 0.38461538
#  [49] 0.25641026 0.25641026 0.20512821 0.25641026 0.15384615 0.23076923
#  [55] 0.33333333 0.30769231 0.35897436 0.25641026 0.25641026 0.00000000
#  [61] 0.25641026 0.28205128 0.10256410 0.28205128 0.23076923 0.33333333
#  [67] 0.30769231 0.25641026 0.23076923 0.35897436 0.28205128 0.23076923
#  [73] 0.35897436 0.20512821 0.38461538 0.28205128 0.30769231 0.23076923
# ...

# %%
par(bg="white")
plot.ts(pi)
# Out:
# plot without title
